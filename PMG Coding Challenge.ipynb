# %%
# Import packages
import pandas as pd


# Add filename column to the clothing data
df1 = pd.read_csv('clothing.csv')
df1["filename"] = 'clothing.csv'


# Add filename column to the accessories data
df2 = pd.read_csv('accessories.csv')
df2["filename"] = 'accessories.csv'


# Combine the two data frames into a single dataframe
combined_df = pd.merge(df1, df2, how='outer')


# Export the combined dataframe as a csv file
combined_df.to_csv('result.csv')

# %%
pd.read_csv('result.csv')
# Out:
#                                             email_hash   category  \
# 0    b9f6f22276c919da793da65c76345ebb0b072257d12402...    Blouses
# 1    c2b5fa9e09ef2464a2b9ed7e351a5e1499823083c05791...     Shirts
# 2    faaee0ff7d06b05313ecb75d46a9aed014b11023ca1af5...    Blouses
# 3    5cd72da5035f2b36b604a16efc639cd04b6cfae7e487dc...     Shirts
# 4    00449a86bb34e443a5f84635661f63514574a030a15e2e...  Cardigans
# ..                                                 ...        ...
# 337  1f89b9e5e91e28b448103d8d14c8802382523934d439b9...   Satchels
# 338  957f3cdcd5a5f9dcc0137377648b939c60d2fbb980110c...    Watches
# 339  03ec8c2e6a17903af7f2a0b604127f91a6be38caa04d84...   Satchels
# 340  3b13daf29e360d56a4e80046c763bd925b8cbe60870d5c...   Satchels
# 341  99f59bddbb78a2ee92b520dd1674ae986f406809d6a1ea...   Satchels
#
#             filename
# 0       clothing.csv
# 1       clothing.csv
# 2       clothing.csv
# 3       clothing.csv
# 4       clothing.csv
# ..               ...
# ...
